# %% [markdown]
# # Hola Nestro
#
# ## Mi primer codigo

# %%
def print_custom_message(message):
  """Prints a custom message."""
  print(message)

# %%
# Example of how to use the function
print_custom_message('Hello from my custom function!')
print_custom_message('This is another message.')
# Out:
# Hello from my custom function!
# This is another message.
